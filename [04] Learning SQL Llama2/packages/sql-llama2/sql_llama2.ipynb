# %% [markdown]
# ## Run Template
#
# In `server.py`, set -
# ```
# add_routes(app, chain, path="/sql_llama2")
# ```
#
# This template includes an example DB of 2023 NBA rosters.
#
# We can  ask questions related to NBA players.

# %%
from langserve.client import RemoteRunnable

sql_app = RemoteRunnable("http://localhost:8000/sql_llama2")
sql_app.invoke({"question": "What team is Klay Thompson on?"})
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Python312\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Python312\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#
# ...
